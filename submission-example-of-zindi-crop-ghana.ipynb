# %%
import pandas as pd
df = pd.read_csv('/kaggle/input/ghana-crop-disease-detection-data/Train.csv')
unique_classes = df['class'].unique()
class_mapping = {cls: idx for idx, cls in enumerate(unique_classes)}
print(class_mapping)
# Out:
# {'Pepper_Bacterial_Spot': 0, 'Pepper_Fusarium': 1, 'Corn_Cercospora_Leaf_Spot': 2, 'Corn_Common_Rust': 3, 'Tomato_Early_Blight': 4, 'Pepper_Septoria': 5, 'Tomato_Septoria': 6, 'Pepper_Leaf_Curl': 7, 'Pepper_Leaf_Mosaic': 8, 'Corn_Streak': 9, 'Corn_Healthy': 10, 'Pepper_Healthy': 11, 'Tomato_Healthy': 12, 'Pepper_Late_Blight': 13, 'Tomato_Late_Blight': 14, 'Pepper_Cercospora': 15, 'Tomato_Fusarium': 16, 'Pepper_Leaf_Blight': 17, 'Tomato_Leaf_Curl': 18, 'Tomato_Bacterial_Spot': 19, 'Tomato_Mosaic': 20, 'Pepper_Early_Blight': 21, 'Corn_Northern_Leaf_Blight': 22}

# %%
# import nbformat

# # Path to the notebook
# notebook_path = '/kaggle/input/ghana-csv-data-starter-notebook/Rail_Challenge_Starter.ipynb'  # Update this with the correct path

# # Load the notebook
# with open(notebook_path, 'r') as f:
#     notebook_content = nbformat.read(f, as_version=4)

# # Extract code cells
# code_cells = [cell['source'] for cell in notebook_content.cells if cell.cell_type == 'code']

# # Print the code cells
# for i, code in enumerate(code_cells):
#     print(f"Code Cell {i + 1}:\n{code}\n")

# %%
# Import libraries
# !pip install ultralytics
import pandas as pd
import os
from pathlib import Path
import shutil
from sklearn.model_selection import train_test_split
from tqdm.notebook import tqdm
import cv2
import yaml
import matplotlib.pyplot as plt
from ultralytics import YOLO
import multiprocessing



# Set the data directory
DATA_DIR = Path('/kaggle/input/ghana-crop-disease-detection-data')

# Load train and test files
train = pd.read_csv(DATA_DIR / 'Train.csv')
test = pd.read_csv(DATA_DIR / 'Test.csv')
ss = pd.read_csv(DATA_DIR / 'SampleSubmission.csv')

# Add an image_path column
train['image_path'] = [Path('/kaggle/input/ghana-crop-disease-detection-data/images/' + x) for x in train.Image_ID]
test['image_path'] = [Path('/kaggle/input/ghana-crop-disease-detection-data/images/' + x) for x in test.Image_ID]

# Map string classes to integers (label encoding targets)
train['class_id'] = train['class'].map(
    {'Pepper_Bacterial_Spot': 0, 'Pepper_Fusarium': 1, 'Corn_Cercospora_Leaf_Spot': 2, 'Corn_Common_Rust': 3, 'Tomato_Early_Blight': 4, 'Pepper_Septoria': 5, 'Tomato_Septoria': 6, 'Pepper_Leaf_Curl': 7, 'Pepper_Leaf_Mosaic': 8, 'Corn_Streak': 9, 'Corn_Healthy': 10, 'Pepper_Healthy': 11, 'Tomato_Healthy': 12, 'Pepper_Late_Blight': 13, 'Tomato_Late_Blight': 14, 'Pepper_Cercospora': 15, 'Tomato_Fusarium': 16, 'Pepper_Leaf_Blight': 17, 'Tomato_Leaf_Curl': 18, 'Tomato_Bacterial_Spot': 19, 'Tomato_Mosaic': 20, 'Pepper_Early_Blight': 21, 'Corn_Northern_Leaf_Blight': 22})

# Split data into training and validation
train_unique_imgs_df = train.drop_duplicates(subset=['Image_ID'], ignore_index=True)
X_train, X_val = train_test_split(train_unique_imgs_df, test_size=0.25, stratify=train_unique_imgs_df['class'], random_state=42)

X_train = train[train.Image_ID.isin(X_train.Image_ID)]
X_val = train[train.Image_ID.isin(X_val.Image_ID)]

# Check the shapes of training and validation data
print(X_train.shape, X_val.shape)

# Define directories for images and labels
TRAIN_IMAGES_DIR = Path('/kaggle/working/train/images')
VAL_IMAGES_DIR = Path('/kaggle/working/val/images')
TEST_IMAGES_DIR = Path('/kaggle/working/test/images')
TRAIN_LABELS_DIR = Path('/kaggle/working/train/labels')
VAL_LABELS_DIR = Path('/kaggle/working/val/labels')
TEST_LABELS_DIR = Path('/kaggle/working/test/labels')

# Create necessary directories
for DIR in [TRAIN_IMAGES_DIR, VAL_IMAGES_DIR, TEST_IMAGES_DIR, TRAIN_LABELS_DIR, VAL_LABELS_DIR, TEST_LABELS_DIR]:
    if DIR.exists():
        shutil.rmtree(DIR)
    DIR.mkdir(parents=True, exist_ok=True)

# Copy train, val, and test images to their respective dirs
for img in tqdm(X_train.image_path.unique()):
    shutil.copy(img, TRAIN_IMAGES_DIR / img.parts[-1])

for img in tqdm(X_val.image_path.unique()):
    shutil.copy(img, VAL_IMAGES_DIR / img.parts[-1])

for img in tqdm(test.image_path.unique()):
    shutil.copy(img, TEST_IMAGES_DIR / img.parts[-1])

# Function to convert the bounding boxes to YOLO format and save them
def save_yolo_annotation(row):
    image_path, class_id, output_dir = row['image_path'], row['class_id'], row['output_dir']

    img = cv2.imread(str(image_path))
    if img is None:
        raise ValueError(f"Could not read image from path: {image_path}")

    height, width, _ = img.shape
    label_file = Path(output_dir) / f"{Path(image_path).stem}.txt"

    ymin, xmin, ymax, xmax = row['ymin'], row['xmin'], row['ymax'], row['xmax']

    # Normalize the coordinates
    x_center = (xmin + xmax) / 2 / width
    y_center = (ymin + ymax) / 2 / height
    bbox_width = (xmax - xmin) / width
    bbox_height = (ymax - ymin) / height

    with open(label_file, 'a') as f:
        f.write(f"{class_id} {x_center:.6f} {y_center:.6f} {bbox_width:.6f} {bbox_height:.6f}\n")

# Parallelize the annotation saving process
def process_dataset(dataframe, output_dir):
    dataframe['output_dir'] = output_dir
    with multiprocessing.Pool() as pool:
        list(tqdm(pool.imap(save_yolo_annotation, dataframe.to_dict('records')), total=len(dataframe)))

# Save train and validation labels to their respective dirs
process_dataset(X_train, TRAIN_LABELS_DIR)
process_dataset(X_val, VAL_LABELS_DIR)

# Create a data.yaml file required by YOLO
class_names = train['class'].unique().tolist()
num_classes = len(class_names)

data_yaml = {
    'train': str(TRAIN_IMAGES_DIR),
    'val': str(VAL_IMAGES_DIR),
    'nc': num_classes,
    'names': class_names
}

# Save the data.yaml file
yaml_path = Path('data.yaml')
with open(yaml_path, 'w') as file:
    yaml.dump(data_yaml, file, default_flow_style=False)

# Load a YOLO pretrained model
model = YOLO('yolov8s.pt')
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.26-py3-none-any.whl.metadata (35 kB)
# Requirement already satisfied: numpy>=1.23.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (3.7.5)
# Requirement already satisfied: opencv-python>=4.6.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (4.10.0.84)
# Requirement already satisfied: pillow>=7.1.2 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (10.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (1.14.1)
# Requirement already satisfied: torch>=1.8.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (2.4.0)
# Requirement already satisfied: torchvision>=0.9.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (0.19.0)
# Requirement already satisfied: tqdm>=4.64.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (4.66.4)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from ultralytics) (5.9.3)
# Requirement already satisfied: py-cpuinfo in /opt/conda/lib/python3.10/site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (0.12.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.10-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (21.3)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.1.4->ultralytics) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.1.4->ultralytics) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (2024.8.30)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.15.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (1.13.3)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.1.4)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (2024.6.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)
# Downloading ultralytics-8.3.26-py3-none-any.whl (878 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 879.0/879.0 kB 31.8 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.10-py3-none-any.whl (26 kB)
# Installing collected packages: ultralytics-thop, ultralytics
# Successfully installed ultralytics-8.3.26 ultralytics-thop-2.0.10
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# (30777, 9) (10252, 9)
#   0%|          | 0/3676 [00:00<?, ?it/s]
#   0%|          | 0/1226 [00:00<?, ?it/s]
#   0%|          | 0/2101 [00:00<?, ?it/s]
# /tmp/ipykernel_30/1866894355.py:91: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['output_dir'] = output_dir
#   0%|          | 0/30777 [00:00<?, ?it/s]
# /tmp/ipykernel_30/1866894355.py:91: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['output_dir'] = output_dir
#   0%|          | 0/10252 [00:00<?, ?it/s]
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8s.pt to 'yolov8s.pt'...
# 100%|██████████| 21.5M/21.5M [00:00<00:00, 354MB/s]

# %%
model.train(
    data='data.yaml',          # Path to the dataset configuration
    epochs=10,                 # Number of epochs
    imgsz=540,               # Image size
    batch=16,                  # Batch size
    device='cpu',               # Use the first GPU (0 for the first GPU)
    patience=3                # Number of epochs with no improvement after which training will stop
)

# Validate the model on the validation seta
model.val()

# Make predictions on test images and save them to a CSV file
image_files = os.listdir(TEST_IMAGES_DIR)
all_data = []

for image_file in tqdm(image_files):
    img_path = os.path.join(TEST_IMAGES_DIR, image_file)
    results = model(img_path)

    boxes = results[0].boxes.xyxy.tolist()
    classes = results[0].boxes.cls.tolist()
    confidences = results[0].boxes.conf.tolist()
    names = results[0].names
    
    incorrect_prediction = 0 
    
    if not boxes:
        incorrect_prediction = incorrect_prediction +   1 
        all_data.append({
            'Image_ID': image_file,
            'class': 'NEG',
            'confidence': 1.0,
            'ymin': 0,
            'xmin': 0,
            'ymax': 0,
            'xmax': 0
        })
    else:
        for box, cls, conf in zip(boxes, classes, confidences):
            x1, y1, x2, y2 = box
            detected_class = names[int(cls)]

            all_data.append({
                'Image_ID': image_file,
                'class': detected_class,
                'confidence': conf,
                'ymin': y1,
                'xmin': x1,
                'ymax': y2,
                'xmax': x2
            })
print(f'========== Total Incorrect predction or dummy prediction {incorrect_prediction}================')
# Convert the results to a DataFrame and save it
sub = pd.DataFrame(all_data)
sub.to_csv('/kaggle/working/benchmark_submission.csv', index=False)
# Out:
# Ultralytics 8.3.26 🚀 Python-3.10.14 torch-2.4.0 CPU (Intel Xeon 2.00GHz)
# engine/trainer: task=detect, mode=train, model=yolov8s.pt, data=data.yaml, epochs=10, time=None, patience=3, batch=16, imgsz=540, save=True, save_period=-1, cache=False, device=cpu, workers=8, project=None, name=train, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf'...
# 100%|██████████| 755k/755k [00:00<00:00, 41.0MB/s]
# 2024-10-31 19:06:39,184	INFO util.py:124 -- Outdated packages:
#   ipywidgets==7.7.1 found, needs ipywidgets>=8
# Run `pip install -U ipywidgets`, then restart the notebook server for rich notebook output.
# 2024-10-31 19:06:39,727	INFO util.py:124 -- Outdated packages:
#   ipywidgets==7.7.1 found, needs ipywidgets>=8
# Run `pip install -U ipywidgets`, then restart the notebook server for rich notebook output.
# Overriding model.yaml nc=80 with nc=23
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.block.C2f             [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    591360  ultralytics.nn.modules.block.C2f             [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.block.C2f             [768, 512, 1]
#  22        [15, 18, 21]  1   2124949  ultralytics.nn.modules.head.Detect           [23, [128, 256, 512]]
# Model summary: 225 layers, 11,144,501 parameters, 11,144,485 gradients, 28.7 GFLOPs
#
# Transferred 349/355 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/detect/train', view at http://localhost:6006/
# Freezing layer 'model.22.dfl.conv.weight'
# WARNING ⚠️ imgsz=[540] must be multiple of max stride 32, updating to [544]
# train: Scanning /kaggle/working/train/labels... 3676 images, 0 backgrounds, 0 corrupt: 100%|██████████| 3676/3676 [00:05<00:00, 726.63it/s]
# train: New cache created: /kaggle/working/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# /opt/conda/lib/python3.10/site-packages/albumentations/__init__.py:13: UserWarning: A new version of Albumentations is available: 1.4.20 (you have 1.4.17). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# val: Scanning /kaggle/working/val/labels... 1226 images, 0 backgrounds, 0 corrupt: 100%|██████████| 1226/1226 [00:01<00:00, 1002.54it/s]
# val: New cache created: /kaggle/working/val/labels.cache
# Plotting labels to runs/detect/train/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.00037, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# TensorBoard: model graph visualization added ✅
# Image sizes 544 train, 544 val
# Using 0 dataloader workers
# Logging results to runs/detect/train
# Starting training for 10 epochs...
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/10         0G       2.68      4.564      1.913        211        544: 100%|██████████| 230/230 [38:57<00:00, 10.16s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 39/39 [04:21<00:00,  6.71s/it]
#                    all       1226      10252      0.371      0.128     0.0644     0.0263
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/10         0G      2.384      2.939      1.666        132        544: 100%|██████████| 230/230 [41:27<00:00, 10.81s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 39/39 [04:19<00:00,  6.66s/it]
#                    all       1226      10252      0.387      0.166     0.0878     0.0343
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/10         0G       2.34      2.681       1.62         68        544: 100%|██████████| 230/230 [42:06<00:00, 10.99s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 39/39 [04:21<00:00,  6.70s/it]
#                    all       1226      10252      0.284      0.211      0.108     0.0427
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/10         0G      2.284      2.523      1.599         85        544: 100%|██████████| 230/230 [42:01<00:00, 10.96s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 39/39 [04:14<00:00,  6.54s/it]
#                    all       1226      10252      0.465      0.207      0.144     0.0572
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/10         0G      2.236      2.381      1.572         49        544: 100%|██████████| 230/230 [41:21<00:00, 10.79s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 39/39 [04:15<00:00,  6.55s/it]
#                    all       1226      10252      0.352       0.24      0.149     0.0602
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/10         0G      2.206      2.265      1.554         61        544: 100%|██████████| 230/230 [39:44<00:00, 10.37s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 39/39 [04:11<00:00,  6.46s/it]
#                    all       1226      10252      0.323      0.234      0.153     0.0631
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/10         0G      2.165      2.164      1.511        112        544: 100%|██████████| 230/230 [40:54<00:00, 10.67s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 39/39 [04:12<00:00,  6.48s/it]
#                    all       1226      10252      0.335      0.265      0.189     0.0773
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/10         0G      2.127      2.092      1.493         77        544: 100%|██████████| 230/230 [41:16<00:00, 10.77s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 39/39 [04:12<00:00,  6.48s/it]
#                    all       1226      10252      0.337       0.28      0.212     0.0875
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/10         0G      2.096      2.026      1.474         99        544: 100%|██████████| 230/230 [41:37<00:00, 10.86s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 39/39 [04:10<00:00,  6.43s/it]
#                    all       1226      10252      0.356      0.295      0.221      0.093
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/10         0G      2.069      1.947      1.454        159        544: 100%|██████████| 230/230 [40:24<00:00, 10.54s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 39/39 [04:12<00:00,  6.47s/it]
#                    all       1226      10252      0.379      0.299      0.234     0.0985
#
# 10 epochs completed in 7.546 hours.
# Optimizer stripped from runs/detect/train/weights/last.pt, 22.5MB
# Optimizer stripped from runs/detect/train/weights/best.pt, 22.5MB
#
# Validating runs/detect/train/weights/best.pt...
# Ultralytics 8.3.26 🚀 Python-3.10.14 torch-2.4.0 CPU (Intel Xeon 2.00GHz)
# Model summary (fused): 168 layers, 11,134,485 parameters, 0 gradients, 28.5 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 39/39 [03:46<00:00,  5.82s/it]
#                    all       1226      10252       0.38      0.299      0.233     0.0985
#  Pepper_Bacterial_Spot        132        476      0.333      0.172      0.165     0.0433
#        Pepper_Fusarium         52        123      0.531      0.545       0.48      0.176
# Corn_Cercospora_Leaf_Spot        202       1600      0.413        0.4      0.359      0.134
#       Corn_Common_Rust         79        442      0.313      0.371      0.272      0.106
#    Tomato_Early_Blight         56        476      0.327      0.363      0.316      0.136
#        Pepper_Septoria         40        697      0.451     0.0212     0.0899     0.0326
#        Tomato_Septoria        119       1588      0.309      0.237      0.188     0.0622
#       Pepper_Leaf_Curl        138        374      0.275      0.267       0.17     0.0553
#     Pepper_Leaf_Mosaic        147        523          1          0       0.02    0.00542
#            Corn_Streak         87        804      0.272        0.5      0.277     0.0905
#           Corn_Healthy         63        415      0.411      0.253      0.248     0.0959
#         Pepper_Healthy         68        184      0.373      0.821      0.588       0.26
#         Tomato_Healthy         59        747      0.497      0.837      0.683      0.425
#     Pepper_Late_Blight         15        135      0.152     0.0222     0.0478     0.0205
#     Tomato_Late_Blight        105        874      0.219      0.206      0.138     0.0502
#      Pepper_Cercospora         41        121      0.375      0.248       0.21     0.0862
#        Tomato_Fusarium         22        268      0.269      0.511      0.316      0.116
#     Pepper_Leaf_Blight         50        121      0.302      0.223      0.182      0.062
#       Tomato_Leaf_Curl         17         93      0.322      0.355      0.268      0.138
#  Tomato_Bacterial_Spot         14        119      0.155     0.0588     0.0758     0.0329
#          Tomato_Mosaic          5         32      0.258      0.219      0.129      0.072
#    Pepper_Early_Blight          2         15          1          0          0          0
# Corn_Northern_Leaf_Blight         12         25      0.174       0.24      0.146     0.0648
# Speed: 0.6ms preprocess, 129.5ms inference, 0.0ms loss, 3.7ms postprocess per image
# Results saved to runs/detect/train
# Ultralytics 8.3.26 🚀 Python-3.10.14 torch-2.4.0 CPU (Intel Xeon 2.00GHz)
# Model summary (fused): 168 layers, 11,134,485 parameters, 0 gradients, 28.5 GFLOPs
# val: Scanning /kaggle/working/val/labels.cache... 1226 images, 0 backgrounds, 0 corrupt: 100%|██████████| 1226/1226 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 77/77 [03:38<00:00,  2.84s/it]
#                    all       1226      10252       0.38      0.299      0.234     0.0986
#  Pepper_Bacterial_Spot        132        476      0.335      0.172      0.165     0.0433
#        Pepper_Fusarium         52        123      0.531      0.545       0.48      0.176
# Corn_Cercospora_Leaf_Spot        202       1600      0.413        0.4      0.359      0.134
#       Corn_Common_Rust         79        442      0.313      0.371      0.272      0.106
#    Tomato_Early_Blight         56        476      0.328      0.363      0.316      0.136
#        Pepper_Septoria         40        697      0.451     0.0212     0.0891     0.0324
#        Tomato_Septoria        119       1588       0.31      0.238      0.188     0.0623
#       Pepper_Leaf_Curl        138        374      0.279      0.267      0.171     0.0556
#     Pepper_Leaf_Mosaic        147        523          1          0       0.02    0.00542
#            Corn_Streak         87        804      0.272        0.5      0.277     0.0905
#           Corn_Healthy         63        415      0.411      0.253      0.248     0.0959
#         Pepper_Healthy         68        184      0.373      0.821      0.588       0.26
#         Tomato_Healthy         59        747      0.498      0.837      0.683      0.425
#     Pepper_Late_Blight         15        135       0.16     0.0222       0.05     0.0215
#     Tomato_Late_Blight        105        874      0.219      0.206      0.138     0.0502
#      Pepper_Cercospora         41        121      0.375      0.248      0.212     0.0868
#        Tomato_Fusarium         22        268      0.269      0.511      0.316      0.116
#     Pepper_Leaf_Blight         50        121      0.305      0.223      0.185      0.063
#       Tomato_Leaf_Curl         17         93      0.322      0.355      0.268      0.138
#  Tomato_Bacterial_Spot         14        119      0.155     0.0588     0.0758     0.0329
#          Tomato_Mosaic          5         32      0.258      0.219      0.129     0.0719
#    Pepper_Early_Blight          2         15          1          0          0          0
# Corn_Northern_Leaf_Blight         12         25      0.174       0.24      0.146     0.0648
# Speed: 0.6ms preprocess, 121.9ms inference, 0.0ms loss, 3.6ms postprocess per image
# Results saved to runs/detect/train2
#   0%|          | 0/2101 [00:00<?, ?it/s]
# image 1/1 /kaggle/working/test/images/id_fhiiqj.jpg: 416x544 (no detections), 176.0ms
# Speed: 3.6ms preprocess, 176.0ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_o22ore.jpg: 384x544 (no detections), 160.8ms
# Speed: 2.2ms preprocess, 160.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 544)
#
# image 1/1 /kaggle/working/test/images/id_tbelfa.jpg: 256x544 (no detections), 125.4ms
# Speed: 1.9ms preprocess, 125.4ms inference, 0.6ms postprocess per image at shape (1, 3, 256, 544)
#
# image 1/1 /kaggle/working/test/images/id_ssurll.jpg: 416x544 (no detections), 136.9ms
# Speed: 2.7ms preprocess, 136.9ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_v4aptq.jpg: 256x544 3 Corn_Cercospora_Leaf_Spots, 89.6ms
# Speed: 1.9ms preprocess, 89.6ms inference, 2.3ms postprocess per image at shape (1, 3, 256, 544)
#
# image 1/1 /kaggle/working/test/images/id_w77o53.jpg: 416x544 (no detections), 133.5ms
# Speed: 2.9ms preprocess, 133.5ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_nvmzaw.jpg: 416x544 2 Pepper_Healthys, 132.5ms
# Speed: 2.9ms preprocess, 132.5ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_flqlyb.jpg: 384x544 2 Tomato_Septorias, 9 Tomato_Healthys, 128.5ms
# Speed: 2.5ms preprocess, 128.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 544)
#
# image 1/1 /kaggle/working/test/images/id_z6726a.jpg: 544x416 (no detections), 168.6ms
# Speed: 2.6ms preprocess, 168.6ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 416)
#
# image 1/1 /kaggle/working/test/images/id_noyj88.jpg: 416x544 (no detections), 147.5ms
# Speed: 3.0ms preprocess, 147.5ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_sulzis.jpg: 256x544 (no detections), 94.1ms
# Speed: 1.9ms preprocess, 94.1ms inference, 0.6ms postprocess per image at shape (1, 3, 256, 544)
#
# image 1/1 /kaggle/working/test/images/id_kcxdy4.jpg: 416x544 (no detections), 132.3ms
# Speed: 2.9ms preprocess, 132.3ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_3sdsm9.jpg: 416x544 1 Pepper_Leaf_Curl, 158.8ms
# Speed: 3.0ms preprocess, 158.8ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_g9a4dh.jpg: 384x544 1 Tomato_Septoria, 19 Tomato_Healthys, 124.2ms
# Speed: 2.5ms preprocess, 124.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 544)
#
# image 1/1 /kaggle/working/test/images/id_gdguzu.jpg: 256x544 3 Corn_Cercospora_Leaf_Spots, 89.9ms
# Speed: 1.9ms preprocess, 89.9ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 544)
#
# image 1/1 /kaggle/working/test/images/id_inejhl.jpg: 256x544 1 Corn_Cercospora_Leaf_Spot, 91.4ms
# Speed: 1.9ms preprocess, 91.4ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 544)
#
# image 1/1 /kaggle/working/test/images/id_ewd3zh.jpg: 416x544 1 Corn_Cercospora_Leaf_Spot, 132.1ms
# Speed: 3.1ms preprocess, 132.1ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_w7p4ns.jpg: 416x544 (no detections), 131.4ms
# Speed: 2.9ms preprocess, 131.4ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_m16rkf.jpg: 544x416 (no detections), 132.9ms
# Speed: 2.7ms preprocess, 132.9ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 416)
#
# image 1/1 /kaggle/working/test/images/id_xufn82.jpg: 256x544 3 Corn_Cercospora_Leaf_Spots, 100.6ms
# Speed: 2.0ms preprocess, 100.6ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 544)
#
# image 1/1 /kaggle/working/test/images/id_od7nys.jpg: 416x544 5 Tomato_Septorias, 132.0ms
# Speed: 2.8ms preprocess, 132.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_gdmets.jpg: 416x544 (no detections), 136.0ms
# Speed: 3.0ms preprocess, 136.0ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_mx1gez.jpg: 416x544 2 Corn_Streaks, 133.6ms
# Speed: 2.9ms preprocess, 133.6ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_hp8wm3.jpg: 384x544 (no detections), 125.3ms
# Speed: 2.5ms preprocess, 125.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 544)
#
# image 1/1 /kaggle/working/test/images/id_j89io5.jpg: 416x544 (no detections), 136.3ms
# Speed: 2.9ms preprocess, 136.3ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_4q5hnv.jpg: 256x544 1 Corn_Cercospora_Leaf_Spot, 95.8ms
# Speed: 1.9ms preprocess, 95.8ms inference, 0.9ms postprocess per image at shape (1, 3, 256, 544)
#
# image 1/1 /kaggle/working/test/images/id_k4ei9p.jpg: 384x544 (no detections), 125.9ms
# Speed: 2.1ms preprocess, 125.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 544)
#
# image 1/1 /kaggle/working/test/images/id_jx29w7.jpg: 256x544 1 Corn_Cercospora_Leaf_Spot, 91.5ms
# Speed: 1.9ms preprocess, 91.5ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 544)
#
# image 1/1 /kaggle/working/test/images/id_z1iiay.jpg: 416x544 (no detections), 133.7ms
# Speed: 2.9ms preprocess, 133.7ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_s79375.jpg: 256x544 1 Corn_Healthy, 91.8ms
# Speed: 2.0ms preprocess, 91.8ms inference, 0.9ms postprocess per image at shape (1, 3, 256, 544)
#
# image 1/1 /kaggle/working/test/images/id_vivcs2.jpg: 416x544 4 Pepper_Healthys, 142.5ms
# Speed: 2.9ms preprocess, 142.5ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_hh1izs.jpg: 256x544 3 Corn_Cercospora_Leaf_Spots, 96.6ms
# Speed: 1.9ms preprocess, 96.6ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 544)
#
# image 1/1 /kaggle/working/test/images/id_4pe56v.jpg: 416x544 2 Tomato_Septorias, 139.4ms
# Speed: 3.1ms preprocess, 139.4ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_j3ni1q.jpg: 416x544 8 Pepper_Healthys, 141.5ms
# Speed: 3.1ms preprocess, 141.5ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_79w816.jpg: 416x544 1 Tomato_Septoria, 135.9ms
# Speed: 2.9ms preprocess, 135.9ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_hjhvmr.jpg: 256x544 1 Corn_Cercospora_Leaf_Spot, 91.1ms
# Speed: 1.9ms preprocess, 91.1ms inference, 0.9ms postprocess per image at shape (1, 3, 256, 544)
#
# image 1/1 /kaggle/working/test/images/id_57tgn5.jpg: 256x544 2 Corn_Cercospora_Leaf_Spots, 93.9ms
# Speed: 1.9ms preprocess, 93.9ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 544)
#
# image 1/1 /kaggle/working/test/images/id_9j3gcw.jpg: 384x544 2 Pepper_Healthys, 124.4ms
# Speed: 2.1ms preprocess, 124.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 544)
#
# image 1/1 /kaggle/working/test/images/id_ts46hy.jpg: 256x544 (no detections), 88.9ms
# Speed: 1.8ms preprocess, 88.9ms inference, 0.7ms postprocess per image at shape (1, 3, 256, 544)
#
# image 1/1 /kaggle/working/test/images/id_53qnw9.jpg: 384x544 (no detections), 123.2ms
# Speed: 2.2ms preprocess, 123.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 544)
#
# image 1/1 /kaggle/working/test/images/id_a18dsf.jpg: 416x544 18 Tomato_Healthys, 137.2ms
# Speed: 3.4ms preprocess, 137.2ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_g7qqgn.jpg: 416x544 (no detections), 133.0ms
# Speed: 2.9ms preprocess, 133.0ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_n8nf5y.jpg: 256x544 1 Corn_Cercospora_Leaf_Spot, 94.0ms
# Speed: 1.9ms preprocess, 94.0ms inference, 0.9ms postprocess per image at shape (1, 3, 256, 544)
#
# image 1/1 /kaggle/working/test/images/id_jfhzw6.jpg: 416x544 (no detections), 133.3ms
# Speed: 3.0ms preprocess, 133.3ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_7r1mme.jpg: 416x544 (no detections), 133.1ms
# Speed: 2.9ms preprocess, 133.1ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_qi4jdh.jpg: 384x544 3 Corn_Streaks, 123.4ms
# Speed: 2.5ms preprocess, 123.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 544)
#
# image 1/1 /kaggle/working/test/images/id_adozns.jpg: 384x544 (no detections), 129.2ms
# Speed: 3.1ms preprocess, 129.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 544)
#
# image 1/1 /kaggle/working/test/images/id_yqe1rf.jpg: 384x544 17 Tomato_Healthys, 127.9ms
# Speed: 2.6ms preprocess, 127.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 544)
#
# image 1/1 /kaggle/working/test/images/id_5em74c.jpg: 384x544 (no detections), 125.9ms
# Speed: 3.2ms preprocess, 125.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 544)
#
# image 1/1 /kaggle/working/test/images/id_7kabk1.jpg: 416x544 (no detections), 140.8ms
# Speed: 3.0ms preprocess, 140.8ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_5uic4r.jpg: 416x544 1 Tomato_Late_Blight, 141.0ms
# Speed: 2.8ms preprocess, 141.0ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_552d3a.jpg: 256x544 (no detections), 92.8ms
# Speed: 1.9ms preprocess, 92.8ms inference, 0.6ms postprocess per image at shape (1, 3, 256, 544)
#
# image 1/1 /kaggle/working/test/images/id_8q3it3.jpg: 256x544 1 Corn_Cercospora_Leaf_Spot, 92.7ms
# Speed: 1.9ms preprocess, 92.7ms inference, 0.9ms postprocess per image at shape (1, 3, 256, 544)
#
# image 1/1 /kaggle/working/test/images/id_6n3beb.jpg: 416x544 4 Tomato_Healthys, 3 Tomato_Leaf_Curls, 137.9ms
# Speed: 2.9ms preprocess, 137.9ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_htot13.jpg: 256x544 (no detections), 92.2ms
# Speed: 1.9ms preprocess, 92.2ms inference, 0.6ms postprocess per image at shape (1, 3, 256, 544)
#
# image 1/1 /kaggle/working/test/images/id_dqol5t.jpg: 416x544 (no detections), 142.7ms
# Speed: 2.9ms preprocess, 142.7ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_1muuin.jpg: 416x544 (no detections), 141.1ms
# Speed: 2.9ms preprocess, 141.1ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_73pdc3.jpg: 416x544 (no detections), 134.9ms
# Speed: 3.0ms preprocess, 134.9ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_rtufv7.jpg: 416x544 5 Tomato_Septorias, 132.2ms
# Speed: 2.8ms preprocess, 132.2ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_ohj76l.jpg: 416x544 (no detections), 135.2ms
# Speed: 3.0ms preprocess, 135.2ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_8khdbi.jpg: 416x544 1 Tomato_Early_Blight, 12 Tomato_Late_Blights, 144.5ms
# Speed: 3.2ms preprocess, 144.5ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_9ulqob.jpg: 384x544 (no detections), 133.4ms
# Speed: 2.5ms preprocess, 133.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 544)
#
# image 1/1 /kaggle/working/test/images/id_eo4vhn.jpg: 416x544 8 Pepper_Healthys, 128.7ms
# Speed: 2.4ms preprocess, 128.7ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_3orain.jpg: 416x544 4 Pepper_Healthys, 125.0ms
# Speed: 2.0ms preprocess, 125.0ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_ostb2x.jpg: 256x544 4 Corn_Cercospora_Leaf_Spots, 1 Corn_Northern_Leaf_Blight, 82.5ms
# Speed: 1.5ms preprocess, 82.5ms inference, 0.8ms postprocess per image at shape (1, 3, 256, 544)
#
# image 1/1 /kaggle/working/test/images/id_d4yx4o.jpg: 416x544 (no detections), 125.3ms
# Speed: 2.4ms preprocess, 125.3ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_uvk63g.jpg: 416x544 (no detections), 125.6ms
# Speed: 2.4ms preprocess, 125.6ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_urhz3c.jpg: 416x544 16 Tomato_Healthys, 128.8ms
# Speed: 2.2ms preprocess, 128.8ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_wk4wx1.jpg: 416x544 (no detections), 130.8ms
# Speed: 2.4ms preprocess, 130.8ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_pr2ali.jpg: 256x544 (no detections), 87.2ms
# Speed: 1.6ms preprocess, 87.2ms inference, 0.5ms postprocess per image at shape (1, 3, 256, 544)
#
# image 1/1 /kaggle/working/test/images/id_y39cpx.jpg: 416x544 (no detections), 126.6ms
# Speed: 2.4ms preprocess, 126.6ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_sw7sjs.jpg: 416x544 1 Tomato_Late_Blight, 125.8ms
# Speed: 2.4ms preprocess, 125.8ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_4fwxuw.jpg: 416x544 1 Tomato_Septoria, 2 Tomato_Late_Blights, 129.1ms
# Speed: 2.4ms preprocess, 129.1ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_dw9fjt.jpg: 416x544 1 Pepper_Leaf_Curl, 130.3ms
# Speed: 2.4ms preprocess, 130.3ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_ino6ds.jpg: 416x544 1 Tomato_Septoria, 128.2ms
# Speed: 2.4ms preprocess, 128.2ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_nb41gm.jpg: 384x544 (no detections), 125.6ms
# Speed: 1.7ms preprocess, 125.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 544)
#
# image 1/1 /kaggle/working/test/images/id_mqwnpr.jpg: 416x544 1 Pepper_Healthy, 126.8ms
# Speed: 2.4ms preprocess, 126.8ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_3s2n38.jpg: 256x544 (no detections), 84.4ms
# Speed: 1.6ms preprocess, 84.4ms inference, 0.5ms postprocess per image at shape (1, 3, 256, 544)
#
# image 1/1 /kaggle/working/test/images/id_buyppa.jpg: 416x544 1 Tomato_Late_Blight, 128.5ms
# Speed: 2.4ms preprocess, 128.5ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_q8rhld.jpg: 416x544 13 Tomato_Early_Blights, 137.6ms
# Speed: 2.9ms preprocess, 137.6ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_rwyl2a.jpg: 416x544 8 Pepper_Healthys, 142.2ms
# Speed: 2.9ms preprocess, 142.2ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_4h2tir.jpg: 416x544 (no detections), 132.6ms
# Speed: 3.0ms preprocess, 132.6ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_zj7h9w.jpg: 256x544 (no detections), 91.6ms
# Speed: 1.9ms preprocess, 91.6ms inference, 0.6ms postprocess per image at shape (1, 3, 256, 544)
#
# image 1/1 /kaggle/working/test/images/id_p2jfwd.jpg: 416x544 (no detections), 133.3ms
# Speed: 2.9ms preprocess, 133.3ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_q3s5ol.jpg: 416x544 1 Tomato_Early_Blight, 3 Tomato_Late_Blights, 132.9ms
# Speed: 3.0ms preprocess, 132.9ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_cg9fg6.jpg: 256x544 (no detections), 99.3ms
# Speed: 1.9ms preprocess, 99.3ms inference, 0.6ms postprocess per image at shape (1, 3, 256, 544)
#
# image 1/1 /kaggle/working/test/images/id_5s6bb8.jpg: 416x544 2 Tomato_Early_Blights, 2 Tomato_Septorias, 134.5ms
# Speed: 2.9ms preprocess, 134.5ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_et1if7.jpg: 256x544 (no detections), 92.1ms
# Speed: 1.9ms preprocess, 92.1ms inference, 0.6ms postprocess per image at shape (1, 3, 256, 544)
#
# image 1/1 /kaggle/working/test/images/id_pbtsqh.jpg: 416x544 (no detections), 135.9ms
# Speed: 2.9ms preprocess, 135.9ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_hf1h63.jpg: 384x544 1 Pepper_Leaf_Curl, 122.8ms
# Speed: 2.4ms preprocess, 122.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 544)
#
# image 1/1 /kaggle/working/test/images/id_q7frx4.jpg: 384x544 (no detections), 123.0ms
# Speed: 2.4ms preprocess, 123.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 544)
#
# image 1/1 /kaggle/working/test/images/id_xxf1sv.jpg: 416x544 (no detections), 130.9ms
# Speed: 2.9ms preprocess, 130.9ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_kee4ko.jpg: 384x544 16 Tomato_Healthys, 122.6ms
# Speed: 2.7ms preprocess, 122.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 544)
#
# image 1/1 /kaggle/working/test/images/id_k9nnhm.jpg: 384x544 (no detections), 122.9ms
# Speed: 2.5ms preprocess, 122.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 544)
#
# image 1/1 /kaggle/working/test/images/id_s6zr2h.jpg: 416x544 5 Tomato_Septorias, 129.9ms
# Speed: 2.9ms preprocess, 129.9ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_ejjcf7.jpg: 384x544 1 Pepper_Bacterial_Spot, 123.3ms
# Speed: 2.5ms preprocess, 123.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 544)
#
# image 1/1 /kaggle/working/test/images/id_myvfll.jpg: 384x544 (no detections), 125.9ms
# Speed: 2.5ms preprocess, 125.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 544)
#
# image 1/1 /kaggle/working/test/images/id_8zdqys.jpg: 416x544 5 Tomato_Late_Blights, 130.1ms
# Speed: 2.8ms preprocess, 130.1ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_82aph4.jpg: 256x544 2 Corn_Cercospora_Leaf_Spots, 91.8ms
# Speed: 1.9ms preprocess, 91.8ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 544)
#
# image 1/1 /kaggle/working/test/images/id_papikx.jpg: 416x544 2 Pepper_Healthys, 140.1ms
# Speed: 3.0ms preprocess, 140.1ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_lpqg7n.jpg: 256x544 (no detections), 92.5ms
# Speed: 1.9ms preprocess, 92.5ms inference, 0.6ms postprocess per image at shape (1, 3, 256, 544)
#
# image 1/1 /kaggle/working/test/images/id_3aeu3j.jpg: 416x544 4 Tomato_Fusariums, 143.5ms
# Speed: 2.9ms preprocess, 143.5ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_p1ajdg.jpg: 384x544 (no detections), 137.2ms
# Speed: 3.1ms preprocess, 137.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 544)
#
# image 1/1 /kaggle/working/test/images/id_vrm5em.jpg: 384x544 (no detections), 125.5ms
# Speed: 2.5ms preprocess, 125.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 544)
#
# image 1/1 /kaggle/working/test/images/id_1j317w.jpg: 416x544 5 Pepper_Healthys, 173.4ms
# Speed: 2.9ms preprocess, 173.4ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_xg9bcg.jpg: 256x544 5 Corn_Cercospora_Leaf_Spots, 98.6ms
# Speed: 1.9ms preprocess, 98.6ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 544)
#
# image 1/1 /kaggle/working/test/images/id_sd752t.jpg: 416x544 1 Tomato_Early_Blight, 4 Tomato_Late_Blights, 133.2ms
# Speed: 3.0ms preprocess, 133.2ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_bbipv7.jpg: 416x544 (no detections), 142.8ms
# Speed: 3.1ms preprocess, 142.8ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_1jqp7v.jpg: 256x544 (no detections), 96.5ms
# Speed: 1.9ms preprocess, 96.5ms inference, 0.7ms postprocess per image at shape (1, 3, 256, 544)
#
# image 1/1 /kaggle/working/test/images/id_xxw1vn.jpg: 416x544 16 Tomato_Healthys, 135.4ms
# Speed: 2.9ms preprocess, 135.4ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_may8mk.jpg: 416x544 4 Pepper_Leaf_Curls, 154.4ms
# Speed: 3.0ms preprocess, 154.4ms inference, 3.2ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_i86q51.jpg: 256x544 1 Corn_Cercospora_Leaf_Spot, 90.4ms
# Speed: 2.4ms preprocess, 90.4ms inference, 0.9ms postprocess per image at shape (1, 3, 256, 544)
#
# image 1/1 /kaggle/working/test/images/id_xpn7p6.jpg: 384x544 8 Tomato_Healthys, 133.3ms
# Speed: 2.5ms preprocess, 133.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 544)
#
# image 1/1 /kaggle/working/test/images/id_eqjzoh.jpg: 384x544 1 Pepper_Healthy, 126.9ms
# Speed: 2.5ms preprocess, 126.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 544)
#
# image 1/1 /kaggle/working/test/images/id_ggwul6.jpg: 384x544 (no detections), 127.7ms
# Speed: 2.5ms preprocess, 127.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 544)
#
# image 1/1 /kaggle/working/test/images/id_2j3vuq.jpg: 384x544 14 Tomato_Healthys, 124.4ms
# Speed: 2.4ms preprocess, 124.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 544)
#
# image 1/1 /kaggle/working/test/images/id_nz8orm.jpg: 416x544 5 Pepper_Fusariums, 134.8ms
# Speed: 3.0ms preprocess, 134.8ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_ey5um9.jpg: 416x544 (no detections), 135.1ms
# Speed: 3.0ms preprocess, 135.1ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_kzwcvk.jpg: 256x544 4 Corn_Cercospora_Leaf_Spots, 92.3ms
# Speed: 1.9ms preprocess, 92.3ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 544)
#
# image 1/1 /kaggle/working/test/images/id_ocqvdq.jpg: 384x544 1 Tomato_Septoria, 124.8ms
# Speed: 2.5ms preprocess, 124.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 544)
#
# image 1/1 /kaggle/working/test/images/id_ksby5v.jpg: 384x544 3 Tomato_Septorias, 1 Tomato_Healthy, 123.3ms
# Speed: 2.6ms preprocess, 123.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 544)
#
# image 1/1 /kaggle/working/test/images/id_9f1lu2.jpg: 416x544 (no detections), 135.4ms
# Speed: 2.8ms preprocess, 135.4ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_ijoh2u.jpg: 416x544 (no detections), 132.8ms
# Speed: 3.0ms preprocess, 132.8ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_i7sqx3.jpg: 256x544 3 Corn_Common_Rusts, 90.8ms
# Speed: 1.9ms preprocess, 90.8ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 544)
#
# image 1/1 /kaggle/working/test/images/id_tt29ba.jpg: 416x544 2 Pepper_Healthys, 134.7ms
# Speed: 2.9ms preprocess, 134.7ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_4q5z3j.jpg: 416x544 (no detections), 134.2ms
# Speed: 3.0ms preprocess, 134.2ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_d1s7jh.jpg: 384x544 (no detections), 123.8ms
# Speed: 2.6ms preprocess, 123.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 544)
#
# image 1/1 /kaggle/working/test/images/id_ngglkj.jpg: 384x544 2 Tomato_Septorias, 123.8ms
# Speed: 2.4ms preprocess, 123.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 544)
#
# image 1/1 /kaggle/working/test/images/id_zl2i2n.jpg: 256x544 2 Corn_Common_Rusts, 92.1ms
# Speed: 1.9ms preprocess, 92.1ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 544)
#
# image 1/1 /kaggle/working/test/images/id_jly7x5.jpg: 256x544 1 Corn_Cercospora_Leaf_Spot, 101.3ms
# Speed: 2.1ms preprocess, 101.3ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 544)
#
# image 1/1 /kaggle/working/test/images/id_pvbaps.jpg: 416x544 1 Tomato_Septoria, 4 Tomato_Healthys, 138.1ms
# Speed: 2.9ms preprocess, 138.1ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_5q1b17.jpg: 416x544 (no detections), 134.1ms
# Speed: 2.9ms preprocess, 134.1ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_14tw4o.jpg: 416x544 10 Tomato_Early_Blights, 1 Tomato_Late_Blight, 134.9ms
# Speed: 3.0ms preprocess, 134.9ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_531xmh.jpg: 416x544 (no detections), 152.2ms
# Speed: 3.3ms preprocess, 152.2ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_1lgvqd.jpg: 256x544 (no detections), 92.2ms
# Speed: 1.9ms preprocess, 92.2ms inference, 0.7ms postprocess per image at shape (1, 3, 256, 544)
#
# image 1/1 /kaggle/working/test/images/id_6byeue.jpg: 416x544 1 Pepper_Leaf_Curl, 138.6ms
# Speed: 3.1ms preprocess, 138.6ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_kvi68g.jpg: 384x544 (no detections), 126.8ms
# Speed: 2.2ms preprocess, 126.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 544)
#
# image 1/1 /kaggle/working/test/images/id_8ufry4.jpg: 384x544 (no detections), 123.8ms
# Speed: 2.5ms preprocess, 123.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 544)
#
# image 1/1 /kaggle/working/test/images/id_y558zl.jpg: 544x416 (no detections), 139.8ms
# Speed: 2.9ms preprocess, 139.8ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 416)
#
# image 1/1 /kaggle/working/test/images/id_zrj147.jpg: 416x544 (no detections), 136.7ms
# Speed: 2.9ms preprocess, 136.7ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_s3gdpu.jpg: 416x544 5 Tomato_Septorias, 136.3ms
# Speed: 2.9ms preprocess, 136.3ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_piu6wg.jpg: 416x544 1 Pepper_Fusarium, 135.7ms
# Speed: 3.0ms preprocess, 135.7ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_onf46j.jpg: 416x544 4 Pepper_Healthys, 131.2ms
# Speed: 3.0ms preprocess, 131.2ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_3kgyvx.jpg: 416x544 2 Tomato_Late_Blights, 133.7ms
# Speed: 3.0ms preprocess, 133.7ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_hue5td.jpg: 416x544 11 Tomato_Septorias, 131.0ms
# Speed: 2.9ms preprocess, 131.0ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_9dqwsl.jpg: 416x544 1 Pepper_Fusarium, 1 Pepper_Healthy, 131.8ms
# Speed: 2.9ms preprocess, 131.8ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_2fic1h.jpg: 416x544 3 Pepper_Healthys, 131.2ms
# Speed: 3.0ms preprocess, 131.2ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_5cj4ox.jpg: 256x544 4 Corn_Cercospora_Leaf_Spots, 91.0ms
# Speed: 1.9ms preprocess, 91.0ms inference, 0.9ms postprocess per image at shape (1, 3, 256, 544)
#
# image 1/1 /kaggle/working/test/images/id_66l41h.jpg: 384x544 (no detections), 129.8ms
# Speed: 3.0ms preprocess, 129.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 544)
#
# image 1/1 /kaggle/working/test/images/id_dkdp5z.jpg: 384x544 (no detections), 120.8ms
# Speed: 2.5ms preprocess, 120.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 544)
#
# image 1/1 /kaggle/working/test/images/id_2lr93j.jpg: 416x544 (no detections), 134.4ms
# Speed: 2.9ms preprocess, 134.4ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_gto1et.jpg: 256x544 8 Corn_Cercospora_Leaf_Spots, 107.7ms
# Speed: 1.9ms preprocess, 107.7ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 544)
#
# image 1/1 /kaggle/working/test/images/id_p6g1la.jpg: 256x544 3 Corn_Common_Rusts, 101.1ms
# Speed: 1.9ms preprocess, 101.1ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 544)
#
# image 1/1 /kaggle/working/test/images/id_5cdy71.jpg: 416x544 1 Pepper_Bacterial_Spot, 154.5ms
# Speed: 3.0ms preprocess, 154.5ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_ywxmb9.jpg: 384x544 (no detections), 131.3ms
# Speed: 2.2ms preprocess, 131.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 544)
#
# image 1/1 /kaggle/working/test/images/id_s73qhu.jpg: 384x544 5 Corn_Streaks, 127.8ms
# Speed: 2.5ms preprocess, 127.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 544)
#
# image 1/1 /kaggle/working/test/images/id_xfdwqt.jpg: 256x544 (no detections), 98.8ms
# Speed: 1.9ms preprocess, 98.8ms inference, 0.7ms postprocess per image at shape (1, 3, 256, 544)
#
# image 1/1 /kaggle/working/test/images/id_xvov1o.jpg: 384x544 1 Pepper_Leaf_Curl, 136.6ms
# Speed: 2.5ms preprocess, 136.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 544)
#
# image 1/1 /kaggle/working/test/images/id_lpi7s5.jpg: 384x544 1 Pepper_Bacterial_Spot, 131.7ms
# Speed: 2.2ms preprocess, 131.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 544)
#
# image 1/1 /kaggle/working/test/images/id_b57hwl.jpg: 416x544 1 Pepper_Leaf_Curl, 132.6ms
# Speed: 3.3ms preprocess, 132.6ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_o9cyxm.jpg: 416x544 (no detections), 133.2ms
# Speed: 2.9ms preprocess, 133.2ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_7yi124.jpg: 416x544 5 Pepper_Cercosporas, 143.2ms
# Speed: 2.7ms preprocess, 143.2ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_ixpnes.jpg: 416x544 4 Pepper_Healthys, 140.4ms
# Speed: 5.2ms preprocess, 140.4ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_vhq4kk.jpg: 416x544 4 Pepper_Healthys, 129.9ms
# Speed: 3.3ms preprocess, 129.9ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_nric2j.jpg: 256x544 3 Corn_Cercospora_Leaf_Spots, 91.9ms
# ...
#
# image 1/1 /kaggle/working/test/images/id_72yd92.jpg: 416x544 1 Corn_Streak, 3 Corn_Northern_Leaf_Blights, 141.7ms
# Speed: 2.8ms preprocess, 141.7ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_143s4o.jpg: 256x544 (no detections), 92.4ms
# Speed: 1.9ms preprocess, 92.4ms inference, 0.5ms postprocess per image at shape (1, 3, 256, 544)
#
# image 1/1 /kaggle/working/test/images/id_g2ouyg.jpg: 256x544 4 Corn_Cercospora_Leaf_Spots, 88.9ms
# Speed: 1.9ms preprocess, 88.9ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 544)
#
# image 1/1 /kaggle/working/test/images/id_4y5wkn.jpg: 384x544 5 Corn_Streaks, 128.9ms
# Speed: 2.5ms preprocess, 128.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 544)
#
# image 1/1 /kaggle/working/test/images/id_d2imj9.jpg: 256x544 1 Corn_Common_Rust, 91.4ms
# Speed: 1.9ms preprocess, 91.4ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 544)
#
# image 1/1 /kaggle/working/test/images/id_ifknev.jpg: 256x544 1 Corn_Cercospora_Leaf_Spot, 91.7ms
# Speed: 1.9ms preprocess, 91.7ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 544)
#
# image 1/1 /kaggle/working/test/images/id_txjvk2.jpg: 416x544 (no detections), 134.0ms
# Speed: 2.9ms preprocess, 134.0ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_okguce.jpg: 416x544 2 Tomato_Late_Blights, 137.8ms
# Speed: 3.0ms preprocess, 137.8ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_mu7zqs.jpg: 384x544 1 Pepper_Bacterial_Spot, 123.7ms
# Speed: 2.5ms preprocess, 123.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 544)
#
# image 1/1 /kaggle/working/test/images/id_pn1zzg.jpg: 384x544 1 Tomato_Septoria, 1 Tomato_Healthy, 1 Tomato_Bacterial_Spot, 130.2ms
# Speed: 2.6ms preprocess, 130.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 544)
#
# image 1/1 /kaggle/working/test/images/id_w6pg8k.jpg: 256x544 (no detections), 87.8ms
# Speed: 1.9ms preprocess, 87.8ms inference, 0.6ms postprocess per image at shape (1, 3, 256, 544)
#
# image 1/1 /kaggle/working/test/images/id_5fx7ix.jpg: 416x544 5 Tomato_Early_Blights, 1 Tomato_Late_Blight, 135.5ms
# Speed: 2.9ms preprocess, 135.5ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_z89ixx.jpg: 256x544 1 Corn_Common_Rust, 99.9ms
# Speed: 1.9ms preprocess, 99.9ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 544)
#
# image 1/1 /kaggle/working/test/images/id_cudjiq.jpg: 416x544 (no detections), 135.3ms
# Speed: 2.6ms preprocess, 135.3ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_1flm7s.jpg: 416x544 3 Pepper_Healthys, 137.8ms
# Speed: 3.2ms preprocess, 137.8ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_kikbak.jpg: 384x544 3 Tomato_Fusariums, 135.0ms
# Speed: 2.7ms preprocess, 135.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 544)
#
# image 1/1 /kaggle/working/test/images/id_gmbomg.jpg: 256x544 1 Corn_Cercospora_Leaf_Spot, 93.6ms
# Speed: 1.8ms preprocess, 93.6ms inference, 0.9ms postprocess per image at shape (1, 3, 256, 544)
#
# image 1/1 /kaggle/working/test/images/id_8435o8.jpg: 256x544 1 Corn_Cercospora_Leaf_Spot, 95.7ms
# Speed: 1.9ms preprocess, 95.7ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 544)
#
# image 1/1 /kaggle/working/test/images/id_eairus.jpg: 416x544 13 Tomato_Healthys, 142.4ms
# Speed: 2.8ms preprocess, 142.4ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_hm28eq.jpg: 416x544 (no detections), 138.3ms
# Speed: 3.2ms preprocess, 138.3ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_ifakmt.jpg: 416x544 (no detections), 135.1ms
# Speed: 2.7ms preprocess, 135.1ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_mhlf19.jpg: 256x544 2 Corn_Common_Rusts, 90.7ms
# Speed: 1.9ms preprocess, 90.7ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 544)
#
# image 1/1 /kaggle/working/test/images/id_e7dvme.jpg: 416x544 (no detections), 144.5ms
# Speed: 3.0ms preprocess, 144.5ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_g2b4hm.jpg: 416x544 28 Tomato_Healthys, 136.9ms
# Speed: 2.9ms preprocess, 136.9ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_6eec86.jpg: 384x544 5 Tomato_Healthys, 126.6ms
# Speed: 2.5ms preprocess, 126.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 544)
#
# image 1/1 /kaggle/working/test/images/id_hkv3zh.jpg: 384x544 (no detections), 125.3ms
# Speed: 2.5ms preprocess, 125.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 544)
#
# image 1/1 /kaggle/working/test/images/id_6xxb78.jpg: 256x544 (no detections), 90.3ms
# Speed: 1.9ms preprocess, 90.3ms inference, 0.6ms postprocess per image at shape (1, 3, 256, 544)
#
# image 1/1 /kaggle/working/test/images/id_to9rpm.jpg: 416x544 5 Pepper_Fusariums, 133.5ms
# Speed: 2.9ms preprocess, 133.5ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_55vjcs.jpg: 384x544 (no detections), 126.8ms
# Speed: 2.5ms preprocess, 126.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 544)
#
# image 1/1 /kaggle/working/test/images/id_4ehke9.jpg: 256x544 1 Corn_Common_Rust, 94.9ms
# Speed: 2.0ms preprocess, 94.9ms inference, 0.9ms postprocess per image at shape (1, 3, 256, 544)
#
# image 1/1 /kaggle/working/test/images/id_ssenp5.jpg: 416x544 1 Pepper_Leaf_Curl, 136.9ms
# Speed: 3.1ms preprocess, 136.9ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_8y8wlr.jpg: 416x544 1 Pepper_Healthy, 136.0ms
# Speed: 2.6ms preprocess, 136.0ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_p1qwzh.jpg: 416x544 (no detections), 132.4ms
# Speed: 2.9ms preprocess, 132.4ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_va1qrt.jpg: 416x544 1 Pepper_Healthy, 133.4ms
# Speed: 2.9ms preprocess, 133.4ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_9v3rev.jpg: 416x544 (no detections), 131.8ms
# Speed: 2.9ms preprocess, 131.8ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_g7hao9.jpg: 416x544 (no detections), 131.5ms
# Speed: 2.9ms preprocess, 131.5ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_9l2ay7.jpg: 544x416 2 Pepper_Leaf_Blights, 135.8ms
# Speed: 2.7ms preprocess, 135.8ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 416)
#
# image 1/1 /kaggle/working/test/images/id_hyg81d.jpg: 256x544 5 Corn_Cercospora_Leaf_Spots, 91.7ms
# Speed: 1.9ms preprocess, 91.7ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 544)
#
# image 1/1 /kaggle/working/test/images/id_v3gu1r.jpg: 416x544 (no detections), 133.7ms
# Speed: 2.9ms preprocess, 133.7ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_iq68wc.jpg: 544x416 1 Pepper_Leaf_Curl, 134.2ms
# Speed: 2.7ms preprocess, 134.2ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 416)
#
# image 1/1 /kaggle/working/test/images/id_khgn7q.jpg: 416x544 2 Pepper_Leaf_Curls, 136.7ms
# Speed: 3.0ms preprocess, 136.7ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_p577dw.jpg: 384x544 (no detections), 124.5ms
# Speed: 2.5ms preprocess, 124.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 544)
#
# image 1/1 /kaggle/working/test/images/id_644x7c.jpg: 256x544 (no detections), 91.6ms
# Speed: 1.9ms preprocess, 91.6ms inference, 0.7ms postprocess per image at shape (1, 3, 256, 544)
#
# image 1/1 /kaggle/working/test/images/id_qmuipp.jpg: 416x544 (no detections), 136.6ms
# Speed: 2.9ms preprocess, 136.6ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_w2cysi.jpg: 416x544 1 Pepper_Healthy, 132.2ms
# Speed: 3.0ms preprocess, 132.2ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_625l96.jpg: 416x544 1 Tomato_Healthy, 4 Tomato_Late_Blights, 136.4ms
# Speed: 2.9ms preprocess, 136.4ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_kvrdtv.jpg: 416x544 2 Tomato_Late_Blights, 1 Tomato_Fusarium, 130.0ms
# Speed: 2.9ms preprocess, 130.0ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_bbargq.jpg: 416x544 1 Tomato_Late_Blight, 131.9ms
# Speed: 2.9ms preprocess, 131.9ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_bizwcx.jpg: 416x544 5 Pepper_Fusariums, 134.1ms
# Speed: 2.9ms preprocess, 134.1ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_9lxok1.jpg: 416x544 2 Tomato_Late_Blights, 137.4ms
# Speed: 2.9ms preprocess, 137.4ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_9xmn2m.jpg: 416x544 26 Tomato_Healthys, 132.0ms
# Speed: 2.8ms preprocess, 132.0ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_nob3ix.jpg: 384x544 (no detections), 125.3ms
# Speed: 2.5ms preprocess, 125.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 544)
#
# image 1/1 /kaggle/working/test/images/id_mr5871.jpg: 416x544 1 Tomato_Early_Blight, 1 Tomato_Late_Blight, 137.2ms
# Speed: 2.9ms preprocess, 137.2ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_f8ek1v.jpg: 384x544 3 Pepper_Leaf_Blights, 126.9ms
# Speed: 2.1ms preprocess, 126.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 544)
#
# image 1/1 /kaggle/working/test/images/id_wdnp7s.jpg: 416x544 2 Pepper_Cercosporas, 144.6ms
# Speed: 3.0ms preprocess, 144.6ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_wwaaaj.jpg: 416x544 (no detections), 140.1ms
# Speed: 2.9ms preprocess, 140.1ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_j45fyl.jpg: 256x544 1 Corn_Cercospora_Leaf_Spot, 90.8ms
# Speed: 1.9ms preprocess, 90.8ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 544)
#
# image 1/1 /kaggle/working/test/images/id_1pfyy3.jpg: 416x544 1 Pepper_Bacterial_Spot, 133.9ms
# Speed: 2.9ms preprocess, 133.9ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_j8vsxn.jpg: 416x544 4 Tomato_Early_Blights, 134.2ms
# Speed: 2.9ms preprocess, 134.2ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_9uekrs.jpg: 256x544 1 Corn_Cercospora_Leaf_Spot, 93.6ms
# Speed: 1.9ms preprocess, 93.6ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 544)
#
# image 1/1 /kaggle/working/test/images/id_yfq9e8.jpg: 416x544 1 Tomato_Early_Blight, 8 Tomato_Late_Blights, 136.8ms
# Speed: 2.9ms preprocess, 136.8ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_gea4uj.jpg: 256x544 1 Corn_Healthy, 91.2ms
# Speed: 1.9ms preprocess, 91.2ms inference, 0.9ms postprocess per image at shape (1, 3, 256, 544)
#
# image 1/1 /kaggle/working/test/images/id_fr9mjb.jpg: 416x544 3 Tomato_Healthys, 10 Tomato_Leaf_Curls, 136.9ms
# Speed: 2.9ms preprocess, 136.9ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_et4hex.jpg: 256x544 (no detections), 89.9ms
# Speed: 1.8ms preprocess, 89.9ms inference, 0.6ms postprocess per image at shape (1, 3, 256, 544)
#
# image 1/1 /kaggle/working/test/images/id_4uguai.jpg: 416x544 (no detections), 139.9ms
# Speed: 3.0ms preprocess, 139.9ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_gqrqpj.jpg: 256x544 (no detections), 89.9ms
# Speed: 1.9ms preprocess, 89.9ms inference, 0.6ms postprocess per image at shape (1, 3, 256, 544)
#
# image 1/1 /kaggle/working/test/images/id_euopfo.jpg: 256x544 (no detections), 106.3ms
# Speed: 2.0ms preprocess, 106.3ms inference, 0.7ms postprocess per image at shape (1, 3, 256, 544)
#
# image 1/1 /kaggle/working/test/images/id_ow5rlg.jpg: 416x544 1 Tomato_Septoria, 148.1ms
# Speed: 3.0ms preprocess, 148.1ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_p5m9vg.jpg: 256x544 1 Corn_Common_Rust, 110.6ms
# Speed: 1.9ms preprocess, 110.6ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 544)
#
# image 1/1 /kaggle/working/test/images/id_448jk9.jpg: 416x544 1 Pepper_Cercospora, 164.3ms
# Speed: 3.1ms preprocess, 164.3ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_3fj2ng.jpg: 256x544 2 Corn_Common_Rusts, 91.7ms
# Speed: 1.9ms preprocess, 91.7ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 544)
#
# image 1/1 /kaggle/working/test/images/id_873iil.jpg: 416x544 1 Pepper_Leaf_Curl, 134.6ms
# Speed: 2.9ms preprocess, 134.6ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_7fahu3.jpg: 416x544 3 Tomato_Septorias, 1 Tomato_Late_Blight, 139.4ms
# Speed: 2.9ms preprocess, 139.4ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_inkn3f.jpg: 384x544 1 Tomato_Fusarium, 126.9ms
# Speed: 2.6ms preprocess, 126.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 544)
#
# image 1/1 /kaggle/working/test/images/id_4hcwzu.jpg: 256x544 1 Corn_Cercospora_Leaf_Spot, 91.5ms
# Speed: 1.9ms preprocess, 91.5ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 544)
#
# image 1/1 /kaggle/working/test/images/id_bwv9mn.jpg: 384x544 4 Pepper_Leaf_Blights, 127.1ms
# Speed: 2.2ms preprocess, 127.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 544)
#
# image 1/1 /kaggle/working/test/images/id_zeaeyd.jpg: 416x544 (no detections), 134.4ms
# Speed: 3.0ms preprocess, 134.4ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_7btwd9.jpg: 416x544 (no detections), 136.2ms
# Speed: 3.0ms preprocess, 136.2ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_5zp2z6.jpg: 416x544 8 Pepper_Healthys, 134.8ms
# Speed: 3.1ms preprocess, 134.8ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_8ibswv.jpg: 416x544 1 Pepper_Bacterial_Spot, 135.9ms
# Speed: 3.0ms preprocess, 135.9ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_3h2g1q.jpg: 416x544 (no detections), 134.1ms
# Speed: 3.1ms preprocess, 134.1ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_fybv8t.jpg: 416x544 11 Tomato_Healthys, 134.2ms
# Speed: 2.9ms preprocess, 134.2ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 544)
#
# image 1/1 /kaggle/working/test/images/id_z9bmsi.jpg: 416x544 2 Tomato_Septorias, 1 Tomato_Healthy, 137.0ms
# Speed: 3.0ms preprocess, 137.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 544)
# ========== Total Incorrect predction or dummy prediction 0================

# %%
#apikey for model acessing
# 928e0393be6ece8cbbd9a973386809288cb48eac

"""
Discussion Zindi ::
Stater Notebook Ghana Crop Disease Detection
I have used used   model = YOLO('yolov8m.pt')   pretrained model for refinding on my data sets I have ajust the basic code to refined this model and make submission file. You have to input api key you can get  from this website https://wandb.ai/site/  singup or login if have account  after copy  apikey from   which is used required in accessing pretrained model of YOLO While runing the code.       Here is link  of  Notebook on kaggle () 
"""
